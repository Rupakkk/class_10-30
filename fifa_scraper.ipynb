# %%
import requests
from bs4 import BeautifulSoup
url=BeautifulSoup('https://www.fifa.com/fifa-world-ranking/ranking-table/men/#all','html.parser')
response=requests.get(url)
soup=response.text
soup=BeautifulSoup(soup,'lxml')
table=soup.table
tags=table.find_all('tr')
data=[]
for i in tags:
    data.append(i.text)
# print(data[0])
# print(len(data[1])      
final_output=[]
for i in range(len(data)):
    x=data[i].split('\n')[1:-1]
    final_output.append(x)   
finals=[]
ls=[0,7,13,14,15]
for i in final_output:
    jj=[]
    for j in ls:
        jj.append(i[j])
    finals.append(jj)
finals[0]=['RANK','TEAM','TOTAL POINTS','PREVIOUS POINTS','+/-']    
finals
        
    
import csv
with open('fifa.csv','w') as f:
    for i in finals:
        x=csv.writer(f)
        x.writerow(i)
import pandas as pd
df=pd.read_csv('fifa.csv',encoding='latin',index_col='RANK')
df
# Out:
# C:\Users\hello\anaconda3\lib\site-packages\bs4\__init__.py:417: MarkupResemblesLocatorWarning: "https://www.fifa.com/fifa-world-ranking/ranking-table/men/#all" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
#                         TEAM  TOTAL POINTS  PREVIOUS POINTS  +/-
# RANK
# 1                    Belgium          1780             1780    0
# 2                     France          1755             1755    0
# 3                     Brazil          1743             1743    0
# 4                    England          1670             1670    0
# 5                   Portugal          1662             1662    0
# ...                      ...           ...              ...  ...
# 206                Sri Lanka           853              853    0
# 207        US Virgin Islands           844              844    0
# ...
