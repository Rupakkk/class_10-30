# %%
try:
    b = open('data.csv','x')
    b.close()
except:
    print("The file is already there.")

# %%
import csv
csvfile = open('data.csv')
reader = csv.DictReader(csvfile)
for row in reader:
    print(row)
# Out:
# {'Sn': '1', 'Name': 'Ram', 'Age': '25', 'Address': 'Kathmandu', 'Phone': '9854124536'}
# {'Sn': '2', 'Name': 'Shyam', 'Age': '29', 'Address': 'Pokhara', 'Phone': '9874561265'}
# {'Sn': '3', 'Name': 'Hari', 'Age': '24', 'Address': 'Butwal', 'Phone': '9842153678'}
# {'Sn': '4', 'Name': 'John', 'Age': '35', 'Address': 'Kapan', 'Phone': '981245785'}
# {'Sn': '5', 'Name': 'Rita', 'Age': '32', 'Address': 'Gulmi', 'Phone': '9865214578'}
# {'Sn': '6', 'Name': 'Sita', 'Age': '19', 'Address': 'Bara', 'Phone': '98652354477'}
# {'Sn': '7', 'Name': 'Hari', 'Age': '78', 'Address': 'Kathmandu', 'Phone': '9845123657'}
# {'Sn': '7', 'Name': 'Hari', 'Age': '78', 'Address': 'Kathmandu', 'Phone': '9845123657'}

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#      Name  Age    Address       Phone
# 0     Ram   67  Kathmandu  9856554543
# 1   Shyam   34      Patan  9856554543
# 2    Hari   23       Bara  9856554543
# 3   Nabin   34     Simara  9856554543
# 4    Rita   23   Nagarkot  9856554543
# 5  Sabita   45  Bhaktapur  9845445443

# %%
# pip install pandas
# pip3 install pandas

# %%
import pandas as pd
df = pd.read_csv('data.csv',nrows = 3)
df
# Out:
#     Name  Age    Address       Phone
# 0    Ram   67  Kathmandu  9856554543
# 1  Shyam   34      Patan  9856554543
# 2   Hari   23       Bara  9856554543

# %%
import pandas as pd
df = pd.read_csv('data.csv')
# df.head()
df.tail(3)
# Out:
#      Name  Age    Address       Phone
# 3   Nabin   34     Simara  9856554543
# 4    Rita   23   Nagarkot  9856554543
# 5  Sabita   45  Bhaktapur  9845445443

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df
# Out:
#       Name  Age    Address       Phone
# Sn
# 1      Ram   67  Kathmandu  9856554543
# 2    Shyam   34      Patan  9856554543
# 3     Hari   23       Bara  9856554543
# 4    Nabin   34     Simara  9856554543
# 5     Rita   23   Nagarkot  9856554543
# 6   Sabita   45  Bhaktapur  9845445443

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df.iloc[1:5,0:3]
# Out:
#      Name  Age  Address
# Sn
# 2   Shyam   29  Pokhara
# 3    Hari   24   Butwal
# 4    John   35    Kapan
# 5    Rita   32    Gulmi

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df.loc[2:5]
# Out:
#      Name  Age  Address       Phone
# Sn
# 2   Shyam   29  Pokhara  9874561265
# 3    Hari   24   Butwal  9842153678
# 4    John   35    Kapan   981245785
# 5    Rita   32    Gulmi  9865214578

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Name')
df.loc["Shyam":"Rita"]
# Out:
#        Sn  Age   Address       Phone
# Name
# Shyam   2   34     Patan  9856554543
# Hari    3   23      Bara  9856554543
# Nabin   4   34    Simara  9856554543
# Rita    5   23  Nagarkot  9856554543

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df[df['Age']>30]
# Out:
#       Name  Age    Address       Phone
# Sn
# 1      Ram   67  Kathmandu  9856554543
# 2    Shyam   34      Patan  9856554543
# 4    Nabin   34     Simara  9856554543
# 6   Sabita   45  Bhaktapur  9845445443

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df[df['Address']=="Kathmandu"]
# Out:
#    Name  Age    Address       Phone
# Sn
# 1   Ram   67  Kathmandu  9856554543

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Name',usecols = ['Name','Address'])
df
# Out:
#          Address
# Name
# Ram    Kathmandu
# Shyam    Pokhara
# Hari      Butwal
# John       Kapan
# Rita       Gulmi
# Sita        Bara
# Hari   Kathmandu
# Hari   Kathmandu

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df1 = df[(df['Age']>20) & (df['Address'] == 'Kathmandu')]
df1.to_csv('df1.csv')

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
import csv   
fields=[7,"Hari",78,"Kathmandu",9856554543,"\n"]
f = open('data.csv', 'a')
x = csv.writer(f)
x.writerow(fields)
f.close()

# %%
a = [["Name","Price","Quantity","Total"],['Apple', 100, 2, 200], 
     ['Banana', 200, 3, 600], ['milk', 100, 3, 300]]

import csv   
f = open('data1.csv', 'a')
x = csv.writer(f)
for i in a:
    x.writerow(i)
f.close()

# %%
DictWriter()
DataFrame()
